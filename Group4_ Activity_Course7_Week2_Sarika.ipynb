# %%
import pandas as pd
import numpy as np
#df=pd.read_csv('Automobile_data.csv')
df=pd.read_csv('auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#1) Drop column Origin from the dataset.

df.drop(['origin'], axis=1,inplace=True)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year                   car name
# 0            70  chevrolet chevelle malibu
# 1            70          buick skylark 320
# ...

# %%
# 2) Find out all the missing values in the dataset and replace it with its most appropriate replacement.
df.isnull().sum()
df.replace("?", np.nan, inplace=True)
df.dropna(inplace=True)

# %%
#3)Find and remove duplicate entries for the column ‘ CAR Number’

#first find the duplicate entries
df.duplicated()


df.drop_duplicates(subset=['car name'], keep ='first')
# Out:
#                car name  horsepower
# 116  pontiac grand prix         230

# %%
# 4) Get the basic insights:
# Display the first five and last five rows
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#                     car name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year         car name
# 393          82  ford mustang gl
# 394          82        vw pickup
# 395          82    dodge rampage
# 396          82      ford ranger
# 397          82       chevy s-10

# %%
# Display all the column names in the dataset
print(list(df))
# Out:
# ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'car name']

# %%
# Display the concise summary of your dataset
df.describe(include = 'all')
# Out:
#                mpg   cylinders  displacement horsepower      weight  \
# count   392.000000  392.000000    392.000000        392  392.000000
# unique         NaN         NaN           NaN         93         NaN
# top            NaN         NaN           NaN        150         NaN
# freq           NaN         NaN           NaN         22         NaN
# mean     23.445918    5.471939    194.411990        NaN    0.579297
# std       7.805007    1.705783    104.644004        NaN    0.165253
# min       9.000000    3.000000     68.000000        NaN    0.313813
# 25%      17.000000    4.000000    105.000000        NaN    0.432928
# 50%      22.750000    4.000000    151.000000        NaN    0.545428
# 75%      29.000000    8.000000    275.750000        NaN    0.703259
# max      46.600000    8.000000    455.000000        NaN    1.000000
#
#         acceleration  model year      origin     car name
# count     392.000000  392.000000  392.000000          392
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   car name      398 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 25.0+ KB

# %%
# Display the name of the car with maximum number of horsepower.

#finding maximum horsepower first
max_horsepower=df['horsepower'].max()

df = df [['car name','horsepower']][df.horsepower==max_horsepower]
df
# Out:
#                car name  horsepower
# 116  pontiac grand prix         230

# %%
# Q5) In our dataset, the fuel consumption columns "mpg" and are represented by mpg (miles per gallon) unit. 
# Assume we are developing an application in a country that accept the fuel consumption with L/100km standard. 
#change the name of column to "L/100km".
df.rename(columns={'mpg':'L/100km'}, inplace= True)
df
# Out:
#      L/100km  cylinders  displacement horsepower  weight  acceleration  \
# 0       18.0          8         307.0        130    3504          12.0
# 1       15.0          8         350.0        165    3693          11.5
# 2       18.0          8         318.0        150    3436          11.0
# 3       16.0          8         304.0        150    3433          12.0
# 4       17.0          8         302.0        140    3449          10.5
# ..       ...        ...           ...        ...     ...           ...
# 393     27.0          4         140.0         86    2790          15.6
# 394     44.0          4          97.0         52    2130          24.6
# 395     32.0          4         135.0         84    2295          11.6
# 396     28.0          4         120.0         79    2625          18.6
# 397     31.0          4         119.0         82    2720          19.4
#
#      model year                   car name
# 0            70  chevrolet chevelle malibu
# ...

# %%
# Q6) Normalize the weight column in this dataset.

df['weight'] = df['weight']/df['weight'].max()
df[['weight']].head(10)
# Out:
#      weight
# 0  0.681712
# 1  0.718482
# 2  0.668482
# 3  0.667899
# 4  0.671012
# 5  0.844553
# 6  0.847082
# 7  0.838911
# 8  0.860895
# 9  0.749027

# %%
# Q6) In our dataset, "horsepower" is a real valued variable ranging from 48 to 288, it has a lot of unique values. 
#What if we only care about the price difference between cars with high horsepower, medium horsepower, and little horsepower (3 types)? 
#Can we rearrange them into three ‘bins' to simplify analysis?

#change data type of horsepower from object to int
df["horsepower"]=df["horsepower"].astype(int, copy= True)

bins = np.linspace(min(df['horsepower']), max(df['horsepower']), 4)
bins

group_names = ['Low Horsepower', 'Medium Horsepower', 'High Horsepower']

df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True)

df[['horsepower','horsepower-binned']].head(30)
# Out:
#     horsepower  horsepower-binned
# 0          130  Medium Horsepower
# 1          165  Medium Horsepower
# 2          150  Medium Horsepower
# 3          150  Medium Horsepower
# 4          140  Medium Horsepower
# 5          198    High Horsepower
# 6          220    High Horsepower
# 7          215    High Horsepower
# 8          225    High Horsepower
# 9          190    High Horsepower
# 10         170    High Horsepower
# 11         160  Medium Horsepower
# 12         150  Medium Horsepower
# 13         225    High Horsepower
# 14          95     Low Horsepower
# 15          95     Low Horsepower
# 16          97     Low Horsepower
# 17          85     Low Horsepower
# 18          88     Low Horsepower
# 19          46     Low Horsepower
# 20          87     Low Horsepower
# 21          90     Low Horsepower
# 22          95     Low Horsepower
# 23         113  Medium Horsepower
# 24          90     Low Horsepower
# 25         215    High Horsepower
# ...

# %%
# Q7) Use a histogram to visualize the distribution of bins we created above.

# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

#pyplot.bar(group_names, df["horsepower-binned"].value_counts())

plt.pyplot.hist(df["horsepower"], bins = 3)

# set labels  for axis and plot title
plt.pyplot.xlabel("Horsepower")
plt.pyplot.ylabel("Count")
plt.pyplot.title("Horsepower Bins")
# Out:
# Text(0.5, 1.0, 'Horsepower Bins')

# %%
# Q8) Detect outliers using Z-score for the acceleration column and remove them
df['ZScore']= (df.acceleration-df.acceleration.mean())/df.acceleration.std()

df[(df['ZScore']>3)]
# Out:
#       mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 299  27.2          4         141.0          71  0.620623          24.8
# 394  44.0          4          97.0          52  0.414397          24.6
#
#      model year  origin     car name horsepower-binned    ZSCORE    ZScore
# 299          79       2  peugeot 504    Low Horsepower  3.355973  3.355973
# 394          82       2    vw pickup    Low Horsepower  3.283479  3.283479

# %%
df[(df['ZScore']>2) | (df['ZScore']<-2)]
# Out:
#       mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 5    15.0          8         429.0         198  0.844553          10.0
# 6    14.0          8         454.0         220  0.847082           9.0
# 7    14.0          8         440.0         215  0.838911           8.5
# 8    14.0          8         455.0         225  0.860895          10.0
# 9    15.0          8         390.0         190  0.749027           8.5
# 10   15.0          8         383.0         170  0.693191          10.0
# 11   14.0          8         340.0         160  0.702140           8.0
# 12   15.0          8         400.0         150  0.731712           9.5
# 13   14.0          8         455.0         225  0.600389          10.0
# 59   23.0          4          97.0          54  0.438521          23.5
# 116  16.0          8         400.0         230  0.832296           9.5
# 195  29.0          4          85.0          52  0.395914          22.2
# ...
